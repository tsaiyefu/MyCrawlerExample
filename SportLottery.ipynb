# %%
def NBAparser():
    from selenium import webdriver
    from selenium.webdriver.chrome.options import Options
    import requests
    from bs4 import BeautifulSoup
    chrome_options = Options()
    chrome_options.add_argument('--headless')
    chrome_options.add_argument('--disable-gpu')
    driver = webdriver.Chrome(chrome_options=chrome_options)
    driver.get('https://www.fengyuncai.com/nba/offensivestats.asp?season=2017r') 
    pageSource = driver.page_source

    driver.close()

    sp = BeautifulSoup(pageSource, "lxml")
    data1 = sp.select('#content > div')
    data2 = data1[1].text
    data3 = data2.replace("\n", "\t")
    data4 = data3.replace("\t\t", "\n")
    data5 = data4.replace("\n\n", "\n")
    data6 = data5.replace("\n\t", "\n")
    f = open('C:\\data\\pythonstudy\\sportsdata\\NBA_attack.txt', 'w', encoding = 'UTF-8')
    f.write(data6)
    te1 = data6
    text1.delete(1.0, tk.END)
    text1.insert(tk.END, te1)
    
    #----------------------------defanceparser
    
    chrome_options1 = Options()
    chrome_options1.add_argument('--headless')
    chrome_options1.add_argument('--disable-gpu')
    driver1 = webdriver.Chrome(chrome_options=chrome_options)
    driver1.get('https://www.fengyuncai.com/nba/defensivestats.asp?season=2017r')
    pageSource1 = driver1.page_source

    driver1.close()

    sp1 = BeautifulSoup(pageSource1, "lxml")
    data11 = sp1.select('#content > div')
    data12 = data11[1].text
    data13 = data12.replace("\n", "\t")
    data14 = data13.replace("\t\t", "\n")
    data15 = data14.replace("\n\n", "\n")
    data16 = data15.replace("\n\t", "\n")
    f1 = open('C:\\data\\pythonstudy\\sportsdata\\NBA_defance.txt', 'w', encoding = 'UTF-8')
    f1.write(data16)
    te1 = data16
    text1.delete(1.0, tk.END)
    text1.insert(tk.END, te1)
    
    
#def Soccerparser():
    
def NPBparser():
    from selenium import webdriver
    from selenium.webdriver.chrome.options import Options
    import requests
    from bs4 import BeautifulSoup
    chrome_options = Options()
    chrome_options.add_argument('--headless')
    chrome_options.add_argument('--disable-gpu')
    driver = webdriver.Chrome(chrome_options=chrome_options)
    driver.get('https://www.fengyuncai.com/npb/hittingstats.asp')
    pageSource = driver.page_source

    driver.close()

    sp = BeautifulSoup(pageSource, "lxml")
    data1 = sp.select('#content > div')
    data2 = data1[1].text
    data3 = data2.replace("\n", "\t")
    data4 = data3.replace("\t\t", "\t")
    data5 = data4.replace("\t\t", "\n")
    f = open('C:\\data\\pythonstudy\\sportsdata\\NPB_bat.txt', 'w', encoding = 'UTF-8')
    f.write(data5)
    te1 = data5
    text1.delete(1.0, tk.END)
    text1.insert(tk.END, te1)
    
    #-----------------------------pitch
    
    chrome_options1 = Options()
    chrome_options1.add_argument('--headless')
    chrome_options1.add_argument('--disable-gpu')
    driver1 = webdriver.Chrome(chrome_options=chrome_options)
    driver1.get('https://www.fengyuncai.com/npb/pitchingstats.asp') 
    pageSource1 = driver1.page_source

    driver1.close()

    sp1 = BeautifulSoup(pageSource1, "lxml")
    data11 = sp1.select('#content > div')
    data12 = data11[1].text
    data13 = data12.replace("\n", "\t")
    data14 = data13.replace("\t\t", "\t")
    data15 = data14.replace("\t\t", "\n")
    f1 = open('C:\\data\\pythonstudy\\sportsdata\\NPB_pitch.txt', 'w', encoding = 'UTF-8')
    f1.write(data15)
    te1 = data15
    text1.delete(1.0, tk.END)
    text1.insert(tk.END, te1)

def MLBparser():
    from selenium import webdriver
    from selenium.webdriver.chrome.options import Options
    import requests
    from bs4 import BeautifulSoup
    chrome_options = Options()
    chrome_options.add_argument('--headless')
    chrome_options.add_argument('--disable-gpu')
    driver = webdriver.Chrome(chrome_options=chrome_options)
    driver.get('https://www.fengyuncai.com/mlb/hittingstats.asp')
    pageSource = driver.page_source

    driver.close()

    sp = BeautifulSoup(pageSource, "lxml")
    data1 = sp.select('#content > div')
    data2 = data1[1].text
    data3 = data2.replace("\n", "\t")
    data4 = data3.replace("\t\t", "\n")
    data5 = data4.replace("\n\t", "\n")
    f = open('C:\\data\\pythonstudy\\sportsdata\\MLB_bat.txt', 'w', encoding = 'UTF-8')
    f.write(data5)
    te1 = data5
    text1.delete(1.0, tk.END)
    text1.insert(tk.END, te1)
    
    #------------------------------------------pitch
    
    chrome_options1 = Options()
    chrome_options1.add_argument('--headless')
    chrome_options1.add_argument('--disable-gpu')
    driver1 = webdriver.Chrome(chrome_options=chrome_options)
    driver1.get('https://www.fengyuncai.com/mlb/pitchingstats.asp')
    pageSource1 = driver1.page_source

    driver1.close()

    sp1 = BeautifulSoup(pageSource1, "lxml")
    data11 = sp1.select('#content > div')
    data12 = data11[1].text
    data13 = data12.replace("\n", "\t")
    data14 = data13.replace("\t\t", "\n")
    data15 = data14.replace("\n\t", "\n")
    f1 = open('C:\\data\\pythonstudy\\sportsdata\\MLB_pitch.txt', 'w', encoding = 'UTF-8')
    f1.write(data15)
    te1 = data15
    text1.delete(1.0, tk.END)
    text1.insert(tk.END, te1)
    
import tkinter as tk

win = tk.Tk()
win.geometry("900x640")
win.title("運彩分析")
te1 = "歡迎使用運彩分析"
text1 = tk.Text(win, font = ("標楷體", 14))
text1.insert(tk.END, te1)
text1.place(x = 40, y = 100, width = 700, height = 390)
#text1.config(state = tk.DISABLED)
button1 = tk.Button(win, text = "撈取NBA資料", font = ("標楷體", 13), command = NBAparser)
button1.place(x = 760, y = 100, width = 120, height = 80)
button2 = tk.Button(win, text = "撈取足球資料", font = ("標楷體", 13))
button2.place(x = 760, y = 190, width = 120, height = 80)
button3 = tk.Button(win, text = "撈取日職資料", font = ("標楷體", 13), command = NPBparser)
button3.place(x = 760, y = 280, width = 120, height = 80)
button16 = tk.Button(win, text = "撈取MLB資料", font = ("標楷體", 13), command = MLBparser)
button16.place(x = 760, y = 370, width = 120, height = 80)
button4 = tk.Button(win, text = "分析NBA PK", font = ("標楷體", 13))
button4.place(x = 40, y = 500, width = 120, height = 40)
button5 = tk.Button(win, text = "分析NBA讓分", font = ("標楷體", 13))
button5.place(x = 188, y = 500, width = 120, height = 40)
button6 = tk.Button(win, text = "分析NBA大小", font = ("標楷體", 13))
button6.place(x = 316, y = 500, width = 120, height = 40)
button7 = tk.Button(win, text = "分析足球PK", font = ("標楷體", 13))
button7.place(x = 444, y = 500, width = 120, height = 40)
button8 = tk.Button(win, text = "分析足球讓分", font = ("標楷體", 13))
button8.place(x = 572, y = 500, width = 120, height = 40)
button9 = tk.Button(win, text = "分析足球大小", font = ("標楷體", 13))
button9.place(x = 700, y = 500, width = 120, height = 40)
button10 = tk.Button(win, text = "分析NPB PK", font = ("標楷體", 13))
button10.place(x = 40, y = 570, width = 120, height = 40)
button11 = tk.Button(win, text = "分析NPB讓分", font = ("標楷體", 13))
button11.place(x = 188, y = 570, width = 120, height = 40)
button12 = tk.Button(win, text = "分析NPB大小", font = ("標楷體", 13))
button12.place(x = 316, y = 570, width = 120, height = 40)
button13 = tk.Button(win, text = "分析MLB PK", font = ("標楷體", 13))
button13.place(x = 444, y = 570, width = 120, height = 40)
button14 = tk.Button(win, text = "分析MLB讓分", font = ("標楷體", 13))
button14.place(x = 572, y = 570, width = 120, height = 40)
button15 = tk.Button(win, text = "分析MLB大小", font = ("標楷體", 13))
button15.place(x = 700, y = 570, width = 120, height = 40)


win.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\tkinter\__init__.py", line 1699, in __call__
#     return self.func(*args)
#   File "<ipython-input-1-811d917066be>", line 10, in NBAparser
#     driver.get('https://www.fengyuncai.com/nba/offensivestats.asp?season=2017r')
#   File "C:\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 324, in get
#     self.execute(Command.GET, {'url': url})
#   File "C:\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 312, in execute
#     self.error_handler.check_response(response)
#   File "C:\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.WebDriverException: Message: unknown error: missing or invalid 'entry.level'
#   (Session info: chrome=66.0.3359.181)
# ...

# %%
    import requests
    from bs4 import BeautifulSoup
    url = "https://www.fengyuncai.com/nba/standings.asp"
    html = requests.get(url)
    html.encoding = "utf-8"
    sp = BeautifulSoup(html.text, "html.parser")
    data1 = sp.select('#narrowcontent > div')
    data2 = data1[5].text
    data3 = data2.replace("\n", "\t")
    data4 = data3.replace("\t\t", "\n")
    data5 = data4.replace("\n\t", "\n")
    data6 = data5.replace("\n\n", "\n\t")
    data6
# Out:
# '\n\n東岸\n\n大西洋組\t勝場\t敗場\t勝率\t勝差\t主場\t客場\t大西洋\t中央組\t東南組\t跨聯盟\t連續勝敗\tL5\tL10\n多倫多暴龍\t59\t23\t71.9%\t--\t34-7\t25-16\t12-4\t14-4\t14-4\t19-11\t1連敗\t4-1\t6-4\n波士頓塞爾提克\t55\t27\t67.0%\t4.0\t27-14\t28-13\t12-4\t10-8\t11-7\t22-8\t1連勝\t2-3\t6-4\n費城76人\t52\t30\t63.4%\t7.0\t30-11\t22-19\t9-7\t11-7\t14-4\t18-12\t16連勝\t5-0\t10-0\n紐約尼克\t29\t53\t35.3%\t30.0\t19-22\t10-31\t6-10\t4-14\t7-11\t12-18\t1連勝\t2-3\t3-7\n布魯克林籃網\t28\t54\t34.1%\t31.0\t15-26\t13-28\t1-15\t6-12\t12-6\t9-21\t1連敗\t3-2\t5-5\n中央組\t勝場\t敗場\t勝率\t勝差\t主場\t客場\t大西洋\t中央組\t東南組\t跨聯盟\t連續勝敗\tL5\tL10\n克里夫蘭騎士\t50\t32\t60.9%\t--\t29-12\t21-20\t11-7\t11-5\t13-5\t15-15\t1連敗\t3-2\t7-3\n印第安那溜馬\t48\t34\t58.5%\t2.0\t27-14\t21-20\t11-7\t10-6\t11-7\t16-14\t1連敗\t2-3\t7-3\n密爾瓦基公鹿\t44\t38\t53.6%\t6.0\t25-16\t19-22\t11-7\t6-10\t10-8\t17-13\t1連敗\t3-2\t6-4\n底特律活塞\t39\t43\t47.5%\t11.0\t25-16\t14-27\t7-11\t9-7\t8-10\t15-15\t1連勝\t2-3\t7-3\n芝加哥公牛\t27\t55\t32.9%\t23.0\t17-24\t10-31\t5-13\t4-12\t12-6\t6-24\t4連敗\t1-4\t3-7\n東南組\t勝場\t敗場\t勝率\t勝差\t主場\t客場\t大西洋\t中央組\t東南組\t跨
# ...

# %%
    import requests
    from bs4 import BeautifulSoup
    url = "https://www.fengyuncai.com/mlb/standings.asp"
    html = requests.get(url)
    html.encoding = "utf-8"
    sp = BeautifulSoup(html.text, "html.parser")
    data1 = sp.select('#narrowcontent > div')
    data2 = data1[1].text
    data3 = data2.replace("\n", "\t")
    data4 = data3.replace("\t\t", "\n")
    data4
# Out:
# '\n\n美國聯盟\xa0\xa0\xa0\xa0(黃底:已經取得分區冠軍;灰底:已經進入季後賽)\n\n東區\t勝場\t敗場\t勝率\t勝差\t主場\t客場\t東區\t中區\t西區\t跨聯盟\t連續勝敗\tL5\tL10\n\t紐約洋基\t31\t13\t70.4%\t--\t18-7\t13-6\t11-9\t10-1\t9-2\t1-1\t3連勝\t4-1\t7-3\n\t波士頓紅襪\t32\t15\t68.0%\t0.5\t15-7\t17-8\t20-9\t2-1\t8-5\t2-0\t2連勝\t4-1\t6-4\n\t坦帕灣光芒\t22\t23\t48.8%\t9.5\t8-10\t14-13\t8-13\t9-3\t5-2\t0-5\t1連敗\t4-1\t7-3\n\t多倫多藍鳥\t22\t25\t46.8%\t10.5\t11-15\t11-10\t8-12\t9-3\t4-9\t1-1\t4連敗\t1-4\t2-8\n\t巴爾地摩金鶯\t15\t32\t31.9%\t17.5\t10-13\t5-19\t8-12\t7-10\t0-9\t0-1\t1連勝\t2-3\t5-5\n\t中區\t勝場\t敗場\t勝率\t勝差\t主場\t客場\t東區\t中區\t西區\t跨聯盟\t連續勝敗\tL5\tL10\n\t克里夫蘭印地安\t22\t23\t48.8%\t--\t13-9\t9-14\t4-6\t10-5\t6-10\t2-2\t1連敗\t2-3\t5-5\n\t明尼蘇達雙城\t20\t23\t46.5%\t1.0\t10-11\t10-12\t3-10\t6-2\t5-5\t6-6\t2連勝\t2-3\t5-5\n\t底特律老虎\t20\t27\t42.5%\t3.0\t12-10\t8-17\t6-4\t9-12\t4-6\t1-5\t4連敗\t1-4\t4-6\n\t堪薩斯皇家\t14\t33\t29.7%\t9.0\t7-18\t7-15\t3-12\t10-13\t1-5\t0-3\t3連敗\t1-4\t2-8\n\t芝加哥白襪\t13\t31\t29.5%\t8.5\t6-17\t7-14\t2-5\t6-9\t4-9\t1-8\t1連敗\t3-2\t4-6\n\t西區\t勝場\t敗場\t勝率\t勝差\t主場\t客場\t東區\t中區\t西
# ...

# %%
import pyodbc
file = open("C:\\data\\pythonstudy\\sportsdata\\NBA_attack.txt", "r", encoding = 'UTF-8')
file.readline()
file.readline()
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER=localhost;DATABASE=DB02;UID=sa;PWD=1234')
cursor = cnxn.cursor()

for iread in file:
    print(iread)
    cursor.execute("insert into NBA_attack values(iread)
    rows = cursor.fetchone()
    file.readline()
#   while rows: 
#       print(rows) 
#       rows = cursor.fetchone()
cnxn.commit()
# Out:
#   File "<ipython-input-9-5a92d8a433c4>", line 10
#     cursor.execute("insert into NBA_attack values(iread)
#                                                         ^
# SyntaxError: EOL while scanning string literal

# %%
file = open("C:\\data\\pythonstudy\\sportsdata\\NBA_attack.txt", "r", encoding = 'UTF-8')
file.readline()
file.readline()
data = []
while file.readline():
    newdata = file.readline().replace("\t", ",")
    #print(newdata)
    data.append(newdata)
print(data)
# Out:
# ['波士頓塞爾提克,東岸大西洋組,82,.450,.377,.771,9.35,35.09,44.45,22.46,7.36,4.59,13.32,19.73,104.0\n', '芝加哥公牛,東岸中央組,82,.435,.355,.759,9.63,35.06,44.69,23.45,7.61,3.53,13.30,19.15,102.9\n', '達拉斯獨行俠,西岸西南組,82,.444,.360,.763,8.13,33.13,41.26,22.65,7.03,3.73,11.80,19.24,102.3\n', '底特律活塞,東岸中央組,82,.450,.373,.745,10.13,33.59,43.73,22.78,7.67,3.87,12.80,18.39,103.7\n', '休士頓火箭,西岸西南組,82,.460,.362,.781,9.01,34.45,43.46,21.54,8.54,4.78,13.28,19.47,112.3\n', '洛杉磯快艇,西岸太平洋組,82,.472,.354,.743,10.14,33.75,43.90,22.34,7.68,4.53,14.13,19.97,108.9\n', '曼斐斯灰熊,西岸西南組,82,.444,.352,.786,9.51,31.04,40.56,21.54,7.48,4.86,14.45,23.17,99.3\n', '密爾瓦基公鹿,東岸中央組,82,.478,.355,.783,8.41,31.45,39.86,23.22,8.74,5.40,13.15,21.36,106.4\n', '布魯克林籃網,東岸大西洋組,82,.441,.356,.772,9.64,34.76,44.41,23.67,6.26,4.76,14.24,20.58,106.5\n', '紐約尼克,東岸大西洋組,82,.464,.351,.787,10.46,33.56,44.02,23.31,6.73,5.09,14.22,20.51,104.4\n', '奧蘭多魔術,東岸東南組,82,.452,.351,.757,8.81,32.85,41.67,23.42,7.54,4.89,13.96,19.25,103.4\n', '鳳凰城太陽,西岸太平洋組,82,.442,.334,.741,10.28,33.
# ...
